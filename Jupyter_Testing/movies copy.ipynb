# %%
import pandas as pd

# %%
movies_df = pd.read_csv("C:\\Users\\aojo2\\OneDrive\\Documents\\Git\\Movies_API\\Movies_Data\\movies.csv")

# %%
#Convert these strings into actual lists of dictionaries. Use eval()
movies_df["genres"] = movies_df["genres"].apply(eval)

# %%
genre = "Crime"

for index, row in movies_df.iterrows():
    print("#"*30)
    print(row['title'])
    print("#"*30)
    for genre in row['genres']:
        print(genre['name'])
else:
    print("Invalid Movie")
# Out:
# ##############################
# Avatar
# ##############################
# Action
# Adventure
# Fantasy
# Science Fiction
# ##############################
# Pirates of the Caribbean: At World's End
# ##############################
# Adventure
# Fantasy
# Action
# ##############################
# Spectre
# ##############################
# Action
# Adventure
# Crime
# ##############################
# The Dark Knight Rises
# ##############################
# Action
# Crime
# Drama
# Thriller
# ##############################
# John Carter
# ##############################
# Action
# Adventure
# Science Fiction
# ##############################
# Spider-Man 3
# ##############################
# Fantasy
# Action
# Adventure
# ##############################
# Tangled
# ##############################
# Animation
# Family
# ##############################
# Avengers: Age of Ultron
# ##############################
# Action
# Adventure
# Science Fiction
# ##############################
# ...

# %%
genre = "Action"

movie = "Avatar"

for index, row in movies_df.iterrows():
    print("#"*30)
    print(row['title'])
    print("#"*30)
    for g in row['genres']:
        if genre == g['name']:
            print("Yes")
else:
    print("Invalid Movie")
# Out:
# ##############################
# Avatar
# ##############################
# Yes
# ##############################
# Pirates of the Caribbean: At World's End
# ##############################
# Yes
# ##############################
# Spectre
# ##############################
# Yes
# ##############################
# The Dark Knight Rises
# ##############################
# Yes
# ##############################
# John Carter
# ##############################
# Yes
# ##############################
# Spider-Man 3
# ##############################
# Yes
# ##############################
# Tangled
# ##############################
# ##############################
# Avengers: Age of Ultron
# ##############################
# Yes
# ##############################
# Harry Potter and the Half-Blood Prince
# ##############################
# ##############################
# Batman v Superman: Dawn of Justice
# ##############################
# Yes
# ##############################
# Superman Returns
# ...
